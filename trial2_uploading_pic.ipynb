# %% [markdown]
# <a href="https://colab.research.google.com/github/mahamapara/Trunks-Logs-Object-Classification/blob/master/trial2_uploading_pic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['tile1_p1.png']))
# Out:
#      <input type="file" id="files-0c6f74f0-961b-4388-bbdd-7a633ca1e359" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c6f74f0-961b-4388-bbdd-7a633ca1e359">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tile1_p1.PNG to tile1_p1.PNG
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-765d00fc1d22> in <module>()
#       4
#       5 uploaded = files.upload()
# ----> 6 im = Image.open(BytesIO(uploaded['tile1_p1.jpg']))
#
# KeyError: 'tile1_p1.jpg'

# %%
im = Image.open(BytesIO(uploaded['tile1_p1.PNG']))

# %%
#import matplotlib.pyplot as plt

#plt.imshow(im)
#plt.show()
